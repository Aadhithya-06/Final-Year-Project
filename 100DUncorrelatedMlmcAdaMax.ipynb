# %%
import sys
import os
sys.path.append(os.path.abspath("Pytorch/"))
sys.path.append(os.path.abspath("models/"))

# %%
from FBSNNs import *
from BlackScholesBarenblatt100D import *

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import time

M = 100  # number of trajectories (batch size)
N = 50  # number of time snapshots
D = 100 # number of dimensions
Mm = N ** (1/5)

layers = [D + 1] + 4 * [256] + [1]

Xi = np.array([1.0, 0.5] * int(D / 2))[None, :]
T = 1.0

"Available architectures"
mode = "Naisnet"  # FC and Naisnet are available
activation = "Sine"  # Sine, ReLU and Tanh are available
model = BlackScholesBarenblatt(Xi, T, M, N, D, Mm, layers, mode, activation)

n_iter = 2 * 10**4
lr = 1e-2

# %%
tot = time.time()
print(model.device)
graph = model.train(n_iter, lr)
print("total time:", time.time() - tot, "s")
# Out:
# cuda:0
# It: 0, Loss: 5.578e+05, Y0: 1.056, Time: 0.64, Learning Rate: 1.000e-02
# It: 100, Loss: 4.397e+03, Y0: 76.404, Time: 7.88, Learning Rate: 1.000e-02
# It: 200, Loss: 4.498e+03, Y0: 71.630, Time: 5.89, Learning Rate: 1.000e-02
# It: 300, Loss: 2.662e+03, Y0: 71.574, Time: 5.44, Learning Rate: 1.000e-02
# It: 400, Loss: 1.616e+03, Y0: 72.651, Time: 6.14, Learning Rate: 1.000e-02
# It: 500, Loss: 9.190e+02, Y0: 73.526, Time: 5.47, Learning Rate: 1.000e-02
# It: 600, Loss: 2.005e+03, Y0: 78.569, Time: 5.91, Learning Rate: 1.000e-02
# It: 700, Loss: 6.412e+02, Y0: 73.666, Time: 6.10, Learning Rate: 1.000e-02
# It: 800, Loss: 9.099e+02, Y0: 73.091, Time: 5.52, Learning Rate: 1.000e-02
# It: 900, Loss: 5.531e+02, Y0: 74.462, Time: 5.95, Learning Rate: 1.000e-02
# It: 1000, Loss: 4.869e+02, Y0: 75.740, Time: 5.84, Learning Rate: 1.000e-02
# It: 1100, Loss: 5.541e+02, Y0: 77.351, Time: 6.07, Learning Rate: 1.000e-02
# It: 1200, Loss: 6.730e+02, Y0: 73.507, Time: 5.36, Learning Rate: 1.000e-02
# It: 1300, Loss: 5.421e+02, Y0: 74.101, Time: 5.51, Learning Rate: 1.000e-02
# It: 1400, Loss: 3.552e+02, Y0: 74.659, Time: 6.27, Learning Rate: 1.000e-02
# It: 1500, Loss: 6.475e+02, Y0: 73.515, Time: 6.61, Learning Rate: 1.000e-02
# It: 1600, Loss: 5.216e+02, Y0: 73.795, Time: 6.10, Learning Rate: 1.000e-02
# It: 1700, Loss: 4.447e+02, Y0: 74.842, Time: 6.45, Learning Rate: 1.000e-02
# It: 1800, Loss: 6.003e+02, Y0: 74.743, Time: 6.36, Learning Rate: 1.000e-02
# It: 1900, Loss: 6.623e+02, Y0: 77.909, Time: 6.51, Learning Rate: 1.000e-02
# It: 2000, Loss: 3.449e+02, Y0: 74.835, Time: 5.92, Learning Rate: 1.000e-02
# It: 2100, Loss: 3.433e+02, Y0: 76.204, Time: 6.41, Learning Rate: 1.000e-02
# It: 2200, Loss: 3.029e+02, Y0: 74.920, Time: 6.68, Learning Rate: 1.000e-02
# It: 2300, Loss: 4.055e+02, Y0: 76.255, Time: 6.27, Learning Rate: 1.000e-02
# It: 2400, Loss: 5.154e+02, Y0: 77.909, Time: 6.78, Learning Rate: 1.000e-02
# It: 2500, Loss: 3.591e+02, Y0: 77.371, Time: 6.57, Learning Rate: 1.000e-02
# It: 2600, Loss: 5.185e+02, Y0: 77.559, Time: 6.45, Learning Rate: 1.000e-02
# It: 2700, Loss: 2.920e+02, Y0: 76.541, Time: 7.34, Learning Rate: 1.000e-02
# It: 2800, Loss: 2.460e+03, Y0: 70.544, Time: 19.38, Learning Rate: 1.000e-02
# It: 2900, Loss: 3.022e+02, Y0: 77.172, Time: 28.29, Learning Rate: 1.000e-02
# It: 3000, Loss: 3.504e+02, Y0: 76.183, Time: 17.91, Learning Rate: 1.000e-02
# It: 3100, Loss: 3.191e+02, Y0: 75.578, Time: 6.38, Learning Rate: 1.000e-02
# It: 3200, Loss: 6.070e+02, Y0: 76.710, Time: 5.98, Learning Rate: 1.000e-02
# It: 3300, Loss: 3.348e+02, Y0: 75.299, Time: 7.13, Learning Rate: 1.000e-02
# It: 3400, Loss: 1.914e+03, Y0: 73.776, Time: 6.17, Learning Rate: 1.000e-02
# It: 3500, Loss: 2.749e+02, Y0: 75.064, Time: 5.64, Learning Rate: 1.000e-02
# It: 3600, Loss: 2.454e+02, Y0: 75.315, Time: 5.55, Learning Rate: 1.000e-02
# It: 3700, Loss: 2.773e+02, Y0: 77.337, Time: 6.25, Learning Rate: 1.000e-02
# It: 3800, Loss: 2.573e+02, Y0: 77.365, Time: 5.68, Learning Rate: 1.000e-02
# It: 3900, Loss: 4.972e+02, Y0: 77.219, Time: 6.03, Learning Rate: 1.000e-02
# It: 4000, Loss: 2.560e+02, Y0: 77.503, Time: 4.33, Learning Rate: 1.000e-02
# It: 4100, Loss: 2.423e+02, Y0: 77.609, Time: 3.80, Learning Rate: 1.000e-02
# It: 4200, Loss: 2.535e+02, Y0: 77.318, Time: 3.88, Learning Rate: 1.000e-02
# It: 4300, Loss: 2.411e+02, Y0: 77.662, Time: 12.51, Learning Rate: 1.000e-02
# It: 4400, Loss: 2.997e+02, Y0: 76.393, Time: 21.92, Learning Rate: 1.000e-02
# It: 4500, Loss: 4.480e+02, Y0: 78.187, Time: 22.71, Learning Rate: 1.000e-02
# It: 4600, Loss: 3.613e+02, Y0: 77.648, Time: 18.67, Learning Rate: 1.000e-02
# It: 4700, Loss: 3.792e+02, Y0: 78.118, Time: 8.05, Learning Rate: 1.000e-02
# It: 4800, Loss: 5.000e+02, Y0: 78.457, Time: 3.80, Learning Rate: 1.000e-02
# It: 4900, Loss: 3.457e+02, Y0: 75.123, Time: 3.46, Learning Rate: 1.000e-02
# It: 5000, Loss: 2.073e+02, Y0: 77.238, Time: 3.55, Learning Rate: 1.000e-02
# It: 5100, Loss: 3.274e+02, Y0: 78.038, Time: 3.58, Learning Rate: 1.000e-02
# It: 5200, Loss: 2.441e+02, Y0: 77.708, Time: 3.35, Learning Rate: 1.000e-02
# It: 5300, Loss: 3.679e+02, Y0: 75.836, Time: 3.61, Learning Rate: 1.000e-02
# It: 5400, Loss: 2.146e+02, Y0: 76.417, Time: 3.71, Learning Rate: 1.000e-02
# It: 5500, Loss: 5.055e+02, Y0: 74.468, Time: 3.71, Learning Rate: 1.000e-02
# It: 5600, Loss: 1.582e+02, Y0: 75.831, Time: 4.15, Learning Rate: 1.000e-02
# It: 5700, Loss: 1.668e+02, Y0: 76.504, Time: 3.82, Learning Rate: 1.000e-02
# It: 5800, Loss: 4.710e+02, Y0: 78.374, Time: 4.07, Learning Rate: 1.000e-02
# It: 5900, Loss: 3.038e+02, Y0: 77.687, Time: 3.98, Learning Rate: 1.000e-02
# It: 6000, Loss: 2.311e+02, Y0: 77.701, Time: 3.92, Learning Rate: 1.000e-02
# It: 6100, Loss: 3.460e+02, Y0: 77.304, Time: 3.99, Learning Rate: 1.000e-02
# It: 6200, Loss: 4.091e+02, Y0: 77.962, Time: 3.94, Learning Rate: 1.000e-02
# It: 6300, Loss: 3.278e+02, Y0: 78.010, Time: 3.96, Learning Rate: 1.000e-02
# It: 6400, Loss: 2.929e+02, Y0: 77.581, Time: 4.07, Learning Rate: 1.000e-02
# It: 6500, Loss: 8.998e+02, Y0: 78.218, Time: 3.84, Learning Rate: 1.000e-02
# It: 6600, Loss: 3.174e+02, Y0: 77.209, Time: 4.04, Learning Rate: 1.000e-02
# It: 6700, Loss: 2.634e+02, Y0: 77.299, Time: 3.97, Learning Rate: 1.000e-02
# It: 6800, Loss: 2.962e+02, Y0: 77.304, Time: 3.64, Learning Rate: 1.000e-02
# It: 6900, Loss: 4.171e+02, Y0: 77.653, Time: 4.04, Learning Rate: 1.000e-02
# It: 7000, Loss: 1.819e+02, Y0: 75.108, Time: 3.83, Learning Rate: 1.000e-02
# It: 7100, Loss: 2.671e+02, Y0: 74.792, Time: 3.89, Learning Rate: 1.000e-02
# It: 7200, Loss: 6.999e+02, Y0: 78.047, Time: 3.89, Learning Rate: 1.000e-02
# It: 7300, Loss: 3.651e+02, Y0: 77.690, Time: 3.95, Learning Rate: 1.000e-02
# It: 7400, Loss: 2.200e+02, Y0: 77.482, Time: 3.89, Learning Rate: 1.000e-02
# It: 7500, Loss: 6.383e+02, Y0: 78.309, Time: 3.82, Learning Rate: 1.000e-02
# It: 7600, Loss: 1.584e+02, Y0: 76.944, Time: 3.92, Learning Rate: 1.000e-02
# It: 7700, Loss: 2.100e+02, Y0: 77.411, Time: 4.74, Learning Rate: 1.000e-02
# It: 7800, Loss: 2.883e+02, Y0: 77.416, Time: 6.15, Learning Rate: 1.000e-02
# It: 7900, Loss: 2.472e+02, Y0: 77.471, Time: 18.26, Learning Rate: 1.000e-02
# It: 8000, Loss: 3.407e+02, Y0: 77.361, Time: 16.47, Learning Rate: 1.000e-02
# It: 8100, Loss: 2.646e+02, Y0: 77.821, Time: 7.61, Learning Rate: 1.000e-02
# It: 8200, Loss: 2.700e+02, Y0: 77.967, Time: 6.79, Learning Rate: 1.000e-02
# It: 8300, Loss: 1.957e+02, Y0: 78.159, Time: 7.22, Learning Rate: 1.000e-02
# It: 8400, Loss: 1.553e+02, Y0: 77.446, Time: 7.51, Learning Rate: 1.000e-02
# It: 8500, Loss: 3.039e+02, Y0: 75.551, Time: 27.42, Learning Rate: 1.000e-02
# It: 8600, Loss: 1.643e+02, Y0: 76.762, Time: 35.44, Learning Rate: 1.000e-02
# It: 8700, Loss: 2.297e+02, Y0: 77.627, Time: 26.08, Learning Rate: 1.000e-02
# It: 8800, Loss: 5.028e+02, Y0: 74.337, Time: 7.00, Learning Rate: 1.000e-02
# It: 8900, Loss: 1.324e+02, Y0: 77.369, Time: 6.60, Learning Rate: 1.000e-02
# It: 9000, Loss: 1.989e+02, Y0: 77.625, Time: 6.94, Learning Rate: 1.000e-02
# It: 9100, Loss: 2.991e+02, Y0: 76.507, Time: 6.61, Learning Rate: 1.000e-02
# It: 9200, Loss: 1.106e+02, Y0: 77.802, Time: 7.69, Learning Rate: 1.000e-02
# It: 9300, Loss: 1.715e+02, Y0: 77.509, Time: 7.36, Learning Rate: 1.000e-02
# It: 9400, Loss: 3.127e+02, Y0: 77.831, Time: 7.55, Learning Rate: 1.000e-02
# It: 9500, Loss: 2.109e+02, Y0: 76.846, Time: 7.61, Learning Rate: 1.000e-02
# It: 9600, Loss: 2.412e+02, Y0: 78.337, Time: 7.29, Learning Rate: 1.000e-02
# It: 9700, Loss: 2.056e+02, Y0: 75.326, Time: 7.73, Learning Rate: 1.000e-02
# It: 9800, Loss: 1.134e+02, Y0: 76.041, Time: 7.27, Learning Rate: 1.000e-02
# It: 9900, Loss: 1.422e+02, Y0: 75.330, Time: 7.21, Learning Rate: 1.000e-02
# It: 10000, Loss: 1.640e+02, Y0: 76.243, Time: 7.56, Learning Rate: 1.000e-02
# It: 10100, Loss: 2.360e+02, Y0: 76.284, Time: 7.64, Learning Rate: 1.000e-02
# It: 10200, Loss: 1.142e+02, Y0: 77.168, Time: 7.50, Learning Rate: 1.000e-02
# It: 10300, Loss: 3.729e+02, Y0: 74.919, Time: 7.51, Learning Rate: 1.000e-02
# It: 10400, Loss: 1.895e+02, Y0: 75.556, Time: 19.26, Learning Rate: 1.000e-02
# It: 10500, Loss: 2.327e+02, Y0: 78.005, Time: 22.08, Learning Rate: 1.000e-02
# It: 10600, Loss: 1.752e+02, Y0: 77.805, Time: 6.83, Learning Rate: 1.000e-02
# It: 10700, Loss: 1.171e+03, Y0: 73.175, Time: 6.97, Learning Rate: 1.000e-02
# It: 10800, Loss: 3.977e+02, Y0: 75.043, Time: 6.60, Learning Rate: 1.000e-02
# It: 10900, Loss: 1.543e+02, Y0: 76.306, Time: 8.68, Learning Rate: 1.000e-02
# It: 11000, Loss: 1.069e+02, Y0: 75.942, Time: 35.65, Learning Rate: 1.000e-02
# It: 11100, Loss: 3.099e+02, Y0: 77.970, Time: 33.30, Learning Rate: 1.000e-02
# It: 11200, Loss: 1.290e+02, Y0: 77.021, Time: 8.31, Learning Rate: 1.000e-02
# It: 11300, Loss: 2.732e+02, Y0: 77.088, Time: 6.80, Learning Rate: 1.000e-02
# It: 11400, Loss: 1.207e+02, Y0: 77.477, Time: 7.03, Learning Rate: 1.000e-02
# It: 11500, Loss: 2.471e+02, Y0: 77.819, Time: 6.81, Learning Rate: 1.000e-02
# It: 11600, Loss: 2.296e+02, Y0: 78.011, Time: 8.11, Learning Rate: 1.000e-02
# It: 11700, Loss: 1.361e+02, Y0: 76.511, Time: 7.20, Learning Rate: 1.000e-02
# It: 11800, Loss: 3.031e+02, Y0: 78.136, Time: 7.10, Learning Rate: 1.000e-02
# It: 11900, Loss: 3.115e+02, Y0: 78.489, Time: 7.30, Learning Rate: 1.000e-02
# It: 12000, Loss: 2.175e+02, Y0: 78.662, Time: 7.20, Learning Rate: 1.000e-02
# It: 12100, Loss: 2.008e+02, Y0: 77.462, Time: 13.24, Learning Rate: 1.000e-02
# It: 12200, Loss: 1.753e+02, Y0: 77.979, Time: 12.98, Learning Rate: 1.000e-02
# It: 12300, Loss: 1.583e+02, Y0: 77.693, Time: 12.94, Learning Rate: 1.000e-02
# It: 12400, Loss: 2.468e+02, Y0: 78.650, Time: 13.83, Learning Rate: 1.000e-02
# It: 12500, Loss: 1.301e+02, Y0: 77.868, Time: 47.54, Learning Rate: 1.000e-02
# It: 12600, Loss: 3.104e+02, Y0: 78.541, Time: 13.69, Learning Rate: 1.000e-02
# It: 12700, Loss: 1.584e+02, Y0: 77.609, Time: 15.09, Learning Rate: 1.000e-02
# It: 12800, Loss: 1.123e+02, Y0: 77.600, Time: 56.95, Learning Rate: 1.000e-02
# It: 12900, Loss: 1.380e+02, Y0: 76.006, Time: 41.74, Learning Rate: 1.000e-02
# It: 13000, Loss: 1.227e+02, Y0: 76.584, Time: 13.63, Learning Rate: 1.000e-02
# It: 13100, Loss: 1.133e+02, Y0: 76.587, Time: 13.43, Learning Rate: 1.000e-02
# It: 13200, Loss: 2.371e+02, Y0: 78.084, Time: 13.65, Learning Rate: 1.000e-02
# It: 13300, Loss: 1.544e+02, Y0: 77.884, Time: 13.51, Learning Rate: 1.000e-02
# It: 13400, Loss: 2.056e+02, Y0: 77.748, Time: 13.73, Learning Rate: 1.000e-02
# It: 13500, Loss: 2.388e+02, Y0: 77.857, Time: 13.35, Learning Rate: 1.000e-02
# It: 13600, Loss: 1.077e+02, Y0: 76.359, Time: 13.85, Learning Rate: 1.000e-02
# It: 13700, Loss: 3.113e+02, Y0: 74.081, Time: 13.05, Learning Rate: 1.000e-02
# It: 13800, Loss: 1.964e+02, Y0: 78.225, Time: 14.41, Learning Rate: 1.000e-02
# It: 13900, Loss: 8.864e+01, Y0: 76.666, Time: 43.32, Learning Rate: 1.000e-02
# It: 14000, Loss: 9.534e+01, Y0: 75.558, Time: 13.38, Learning Rate: 1.000e-02
# It: 14100, Loss: 8.350e+01, Y0: 76.556, Time: 13.33, Learning Rate: 1.000e-02
# It: 14200, Loss: 1.605e+02, Y0: 77.588, Time: 46.85, Learning Rate: 1.000e-02
# It: 14300, Loss: 1.597e+02, Y0: 77.322, Time: 44.09, Learning Rate: 1.000e-02
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 tot = time.time()
#       2 print(model.device)
# ----> 3 graph = model.train(n_iter, lr)
#       4 print("total time:", time.time() - tot, "s")
#
# File /vol/bitbucket/aan120/Final-Year-Project/Pytorch/FBSNNs.py:259, in FBSNN.train(self, N_Iter, learning_rate)
#     256 self.optimizer.zero_grad()
#     258 # Fetch a minibatch of time steps and Brownian motion paths
# --> 259 t_batch, W_batch = self.fetch_minibatch()  # M x (N+1) x 1, M x (N+1) x D
#     261 # def closure():
#     262 #     self.optimizer.zero_grad()  # Zero the gradients
#     263 #     loss, X_pred, Y_pred, Y0_pred = self.loss_function(t_batch, W_batch, self.Xi)
#    (...)
#     274
#     275 # Compute the loss for the current batch
#     276 loss, X_pred, Y_pred, Y0_pred = self.loss_function(t_batch, W_batch, self.Xi)
#
# File /vol/bitbucket/aan120/Final-Year-Project/Pytorch/FBSNNs.py:206, in FBSNN.fetch_minibatch(self)
#     204 Dt[:, 1:, :] = dt
#     205 # Generate Brownian increments for each trajectory and time snapshot
# --> 206 DW_uncorrelated = np.sqrt(dt) * np.random.normal(size=(M, N, D))
#     207 DW[:, 1:, :] = DW_uncorrelated # np.einsum('ij,mnj->mni', self.L, DW_uncorrelated) # Apply Cholesky matrix to introduce correlations
#     209 # Cumulatively sum the time steps and Brownian increments to get the actual time values and Brownian paths
#
# KeyboardInterrupt:

# %%
n_iter = 41 * 10**2
lr = 1e-5

# %%
tot = time.time()
print(model.device)
graph = model.train(n_iter, lr)
print("total time:", time.time() - tot, "s")
# Out:
# cuda:0
# It: 19900, Loss: 7.177e+02, Y0: 74.370, Time: 0.40, Learning Rate: 1.000e-05
# It: 20000, Loss: 5.554e+02, Y0: 74.583, Time: 27.06, Learning Rate: 1.000e-05
# It: 20100, Loss: 4.963e+02, Y0: 74.797, Time: 26.54, Learning Rate: 1.000e-05
# It: 20200, Loss: 5.244e+02, Y0: 75.010, Time: 26.64, Learning Rate: 1.000e-05
# It: 20300, Loss: 4.565e+02, Y0: 75.223, Time: 26.80, Learning Rate: 1.000e-05
# It: 20400, Loss: 4.253e+02, Y0: 75.437, Time: 26.57, Learning Rate: 1.000e-05
# It: 20500, Loss: 4.279e+02, Y0: 75.648, Time: 26.83, Learning Rate: 1.000e-05
# It: 20600, Loss: 4.311e+02, Y0: 75.771, Time: 26.40, Learning Rate: 1.000e-05
# It: 20700, Loss: 4.211e+02, Y0: 75.784, Time: 26.70, Learning Rate: 1.000e-05
# It: 20800, Loss: 4.245e+02, Y0: 75.792, Time: 26.69, Learning Rate: 1.000e-05
# It: 20900, Loss: 4.287e+02, Y0: 75.774, Time: 26.63, Learning Rate: 1.000e-05
# It: 21000, Loss: 4.156e+02, Y0: 75.777, Time: 26.58, Learning Rate: 1.000e-05
# It: 21100, Loss: 4.466e+02, Y0: 75.787, Time: 27.00, Learning Rate: 1.000e-05
# It: 21200, Loss: 4.192e+02, Y0: 75.778, Time: 26.29, Learning Rate: 1.000e-05
# It: 21300, Loss: 4.352e+02, Y0: 75.779, Time: 26.32, Learning Rate: 1.000e-05
# It: 21400, Loss: 3.924e+02, Y0: 75.774, Time: 26.85, Learning Rate: 1.000e-05
# It: 21500, Loss: 4.343e+02, Y0: 75.779, Time: 26.57, Learning Rate: 1.000e-05
# It: 21600, Loss: 4.318e+02, Y0: 75.783, Time: 26.44, Learning Rate: 1.000e-05
# It: 21700, Loss: 3.983e+02, Y0: 75.786, Time: 26.71, Learning Rate: 1.000e-05
# It: 21800, Loss: 4.271e+02, Y0: 75.783, Time: 26.45, Learning Rate: 1.000e-05
# It: 21900, Loss: 3.998e+02, Y0: 75.786, Time: 26.45, Learning Rate: 1.000e-05
# It: 22000, Loss: 4.243e+02, Y0: 75.785, Time: 26.66, Learning Rate: 1.000e-05
# It: 22100, Loss: 4.130e+02, Y0: 75.782, Time: 26.97, Learning Rate: 1.000e-05
# It: 22200, Loss: 4.302e+02, Y0: 75.793, Time: 26.72, Learning Rate: 1.000e-05
# It: 22300, Loss: 4.133e+02, Y0: 75.775, Time: 26.55, Learning Rate: 1.000e-05
# It: 22400, Loss: 4.104e+02, Y0: 75.787, Time: 26.89, Learning Rate: 1.000e-05
# It: 22500, Loss: 4.120e+02, Y0: 75.779, Time: 26.77, Learning Rate: 1.000e-05
# It: 22600, Loss: 4.394e+02, Y0: 75.779, Time: 26.72, Learning Rate: 1.000e-05
# It: 22700, Loss: 4.080e+02, Y0: 75.791, Time: 26.37, Learning Rate: 1.000e-05
# It: 22800, Loss: 4.125e+02, Y0: 75.799, Time: 26.88, Learning Rate: 1.000e-05
# It: 22900, Loss: 4.363e+02, Y0: 75.793, Time: 26.73, Learning Rate: 1.000e-05
# It: 23000, Loss: 4.349e+02, Y0: 75.787, Time: 26.79, Learning Rate: 1.000e-05
# It: 23100, Loss: 4.592e+02, Y0: 75.782, Time: 26.65, Learning Rate: 1.000e-05
# It: 23200, Loss: 4.070e+02, Y0: 75.792, Time: 26.83, Learning Rate: 1.000e-05
# It: 23300, Loss: 4.342e+02, Y0: 75.781, Time: 26.63, Learning Rate: 1.000e-05
# It: 23400, Loss: 4.326e+02, Y0: 75.786, Time: 26.57, Learning Rate: 1.000e-05
# It: 23500, Loss: 4.263e+02, Y0: 75.782, Time: 26.79, Learning Rate: 1.000e-05
# It: 23600, Loss: 4.213e+02, Y0: 75.799, Time: 26.60, Learning Rate: 1.000e-05
# It: 23700, Loss: 4.131e+02, Y0: 75.795, Time: 26.77, Learning Rate: 1.000e-05
# It: 23800, Loss: 4.449e+02, Y0: 75.785, Time: 26.35, Learning Rate: 1.000e-05
# It: 23900, Loss: 4.218e+02, Y0: 75.790, Time: 26.62, Learning Rate: 1.000e-05
# total time: 1093.2012882232666 s

# %%
model.load_model("models/BlackScholesBarenblattMLMC100DAdamax.pth")

# %%
graph = model.iteration, model.training_loss

# %%
def figsize(scale, nplots = 1):
    fig_width_pt = 438.17227                        
    inches_per_pt = 1.0/72.27                       
    golden_mean = (np.sqrt(5.0)-1.0)/2.0            
    fig_width = fig_width_pt*inches_per_pt*scale    
    fig_height = nplots*fig_width*golden_mean             
    fig_size = [fig_width,fig_height]
    return fig_size

# %%
np.random.seed(65)
t_test, W_test = model.fetch_minibatch()
X_pred, Y_pred = model.predict(Xi, t_test, W_test)
samples = 5

if type(t_test).__module__ != 'numpy':
    t_test = t_test.cpu().numpy()
if type(X_pred).__module__ != 'numpy':
    X_pred = X_pred.cpu().detach().numpy()
if type(Y_pred).__module__ != 'numpy':
    Y_pred = Y_pred.cpu().detach().numpy()

Y_test = np.reshape(u_exact(T,np.reshape(t_test[0:M, :, :], [-1, 1]), np.reshape(X_pred[0:M, :, :], [-1, D])),
                    [M, -1, 1])

# %%
plt.figure(figsize=figsize(1))
plt.plot(graph[0], graph[1])
plt.xlabel('Iterations')
plt.ylabel('Value')
plt.yscale("log")
plt.title('Evolution of the training loss')
# plt.savefig('Figures/BlackScholesBarenblattMLMC100DLoss1000.pdf')

plt.figure(figsize=figsize(1))
plt.plot(t_test[0:1, :, 0].T, Y_pred[0:1, :, 0].T, 'b', label='Learned $u(t,X_t)$')
plt.plot(t_test[0:1, :, 0].T, Y_test[0:1, :, 0].T, 'r--', label='Exact $u(t,X_t)$')
plt.plot(t_test[0:1, -1, 0], Y_test[0:1, -1, 0], 'ko', label='$Y_T = u(T,X_T)$')

plt.plot(t_test[1:samples, :, 0].T, Y_pred[1:samples, :, 0].T, 'b')
plt.plot(t_test[1:samples, :, 0].T, Y_test[1:samples, :, 0].T, 'r--')
plt.plot(t_test[1:samples, -1, 0], Y_test[1:samples, -1, 0], 'ko')

plt.plot([0], Y_test[0, 0, 0], 'ks', label='$Y_0 = u(0,X_0)$')

plt.xlabel('$t$')
plt.ylabel('$Y_t = u(t,X_t)$')
plt.title(str(D) + '-dimensional Black-Scholes-Barenblatt, ' + model.mode + "-" + model.activation)
plt.legend()
# plt.savefig('Figures/BlackScholesBarenblattMLMC100DPreds1000.pdf')

plt.show()

# %%
errors = np.sqrt((Y_test - Y_pred) ** 2 / Y_test ** 2)
mean_errors = np.mean(errors, 0)
std_errors = np.std(errors, 0)
plt.figure(figsize=figsize(1))
plt.plot(t_test[0, :, 0], mean_errors, 'b', label='mean')
plt.plot(t_test[0, :, 0], mean_errors + 2 * std_errors, 'r--', label='mean + two standard deviations')
plt.xlabel('$t$')
plt.ylabel('relative error')
plt.title(str(D) + '-dimensional Black-Scholes-Barenblatt, ' + model.mode + "-" + model.activation)
plt.legend()
# plt.savefig('Figures/BlackScholesBarenblattMLMC100DErrors1000.pdf')
plt.show()

# %%
model.save_model("models/BlackScholesBarenblattMLMC100DAdamax.pth")
