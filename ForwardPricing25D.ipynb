# %%
import sys
import os
sys.path.append(os.path.abspath("Algorithms/"))
sys.path.append(os.path.abspath("models/"))

# %%
from FBSNNs import *
from ForwardContracts import *

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import time

M = 64  # number of trajectories (batch size)
N = 50 # number of time snapshots
D = 25 # number of dimensions
Mm = N ** (1/5)

layers = [D + 1] + 2 * [45] + [1]

Xi = np.array([1.0] * D)[None, :]
T = 1.0

"Available architectures"
mode = "Naisnet"  # FC and Naisnet are available
activation = "Sine"  # Sine, ReLU and Tanh are available
model = ForwardContracts(Xi, T, M, N, D, Mm, layers, mode, activation)

n_iter = 2*10**4
lr = 1e-3

# %%
model.load_model("models/Forward25D.pth")

# %%
graph = model.iteration, model.training_loss

# %%
n_iter = 11*10**2
lr = 1e-5

# %%
tot = time.time()
print(model.device)
graph = model.train(n_iter, lr)
print("total time:", time.time() - tot, "s")
# Out:
# cuda:0
# It: 19900, Loss: 3.672e-02, Y0: 0.513, Time: 0.08, Learning Rate: 1.000e-05
# It: 20000, Loss: 8.051e-03, Y0: 0.495, Time: 8.25, Learning Rate: 1.000e-05
# It: 20100, Loss: 7.952e-03, Y0: 0.495, Time: 8.29, Learning Rate: 1.000e-05
# It: 20200, Loss: 1.039e-02, Y0: 0.495, Time: 8.37, Learning Rate: 1.000e-05
# It: 20300, Loss: 1.559e-02, Y0: 0.495, Time: 8.31, Learning Rate: 1.000e-05
# It: 20400, Loss: 7.745e-03, Y0: 0.495, Time: 8.28, Learning Rate: 1.000e-05
# It: 20500, Loss: 6.129e-03, Y0: 0.494, Time: 8.25, Learning Rate: 1.000e-05
# It: 20600, Loss: 7.262e-03, Y0: 0.494, Time: 8.22, Learning Rate: 1.000e-05
# It: 20700, Loss: 8.170e-03, Y0: 0.494, Time: 8.27, Learning Rate: 1.000e-05
# It: 20800, Loss: 2.787e-02, Y0: 0.495, Time: 8.27, Learning Rate: 1.000e-05
# It: 20900, Loss: 6.970e-03, Y0: 0.495, Time: 8.20, Learning Rate: 1.000e-05
# total time: 90.95629358291626 s

# %%
np.random.seed(37)
t_test, W_test = model.fetch_minibatch()
X_pred, Y_pred = model.predict(Xi, t_test, W_test)

if type(t_test).__module__ != 'numpy':
    t_test = t_test.cpu().numpy()
if type(X_pred).__module__ != 'numpy':
    X_pred = X_pred.cpu().detach().numpy()
if type(Y_pred).__module__ != 'numpy':
    Y_pred = Y_pred.cpu().detach().numpy()

for i in range(63):
    t_test_i, W_test_i = model.fetch_minibatch()
    X_pred_i, Y_pred_i = model.predict(Xi, t_test_i, W_test_i)
    if type(X_pred_i).__module__ != 'numpy':
        X_pred_i = X_pred_i.cpu().detach().numpy()
    if type(Y_pred_i).__module__ != 'numpy':
        Y_pred_i = Y_pred_i.cpu().detach().numpy()
    if type(t_test_i).__module__ != 'numpy':
        t_test_i = t_test_i.cpu().numpy()
    t_test = np.concatenate((t_test, t_test_i), axis=0)
    X_pred = np.concatenate((X_pred, X_pred_i), axis=0)
    Y_pred = np.concatenate((Y_pred, Y_pred_i), axis=0)

# %%
plt.figure()
plt.plot(graph[0], graph[1])
plt.xlabel('Iterations')
plt.ylabel('Value')
plt.yscale("log")
plt.title('Evolution of the training loss')
plt.show()

# %%
samples = 64

plt.figure()
plt.plot(t_test[0:1, :, 0].T, Y_pred[0:1, :, 0].T, label='Learned $u(t,X_t)$')


plt.plot(t_test[1:samples, :, 0].T, Y_pred[1:samples, :, 0].T)

plt.xlabel('$t$')
plt.ylabel('$Y_t = u(t,X_t)$')
plt.title(str(D) + '-dimensional Black-Scholes-Barenblatt, ' + model.mode + "-" + model.activation)
plt.legend()

plt.show()

# %%
model.save_model("models/Forward25D.pth")
